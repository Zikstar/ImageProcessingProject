# %%
import matplotlib.pyplot as plt
import cv2
from google.colab.patches import cv2_imshow
from PIL import Image
import numpy as np
import os
import torch
import torch.nn as nn
import torchvision.transforms as T
from sklearn.model_selection import train_test_split
from torch.utils.data import Subset
from torchvision.datasets import ImageFolder
from sklearn.metrics import confusion_matrix, classification_report
import pandas as pd


from google.colab import drive
drive.mount('/content/drive')

# After executing the cell above, Drive
# files will be present in "/content/drive/My Drive".
#Second change your current folder to point working folder My Drive
os.chdir("/content/drive/My Drive/")
#os.listdir()
# Out:
# Mounted at /content/drive

# %%
top_path = os.getcwd()
path = os.getcwd() + '/Data'
print(path)
img_size = 64
test_ratio = 0.2
# Out:
# /content/drive/My Drive/Data

# %% [markdown]
# In this method I pre-process images by resizing, converting to grayscale, perform normalization and splitting dataset images into training dataset and testing dataset

# %%
def pre_processing():
    # Get Mean and STD
    mean, std, my_categories = cal_mean_std()

    # Pre_Processing
    image_transforms = T.Compose([
        T.Resize((img_size, img_size)),
        T.Grayscale(),
        T.ToTensor(),
        T.Normalize([mean], [std]),
    ])

    # Get Images
    dataset = ImageFolder(path, transform=image_transforms)

    # splitting dataset, Each category have same number of images
    print("length of dataset = ", len(dataset))
    train_idx, test_idx = train_test_split(list(range(len(dataset))), test_size=test_ratio, stratify=dataset.targets,
                                           random_state=0)
    train = Subset(dataset, train_idx)
    test = Subset(dataset, test_idx)
    
    print("length of training set = ", len(train))
    print("length of testing set = ", len(test))
    
    # load datas
    train_loader = torch.utils.data.DataLoader(train, batch_size=32, shuffle=True, num_workers=2)
    test_loader = torch.utils.data.DataLoader(test, batch_size=len(test), shuffle=False, num_workers=2)

    return train_loader, test_loader, my_categories

'''
A method to calculate the mean and the standard deviation for the dataset,
to be used in the normalization process
'''
def cal_mean_std ():
    # get categories
    my_categories = os.listdir(os.path.basename(path))
    cnt = 0
    data_sum=0
    data_std_sum = 0
    for category in my_categories:
        # get directory for each category
        sub_path = path + '/' + category
        flist = os.listdir(sub_path)
        if '.DS_Store' in flist:
            flist.remove('.DS_Store')
        os.chdir(sub_path)
        for image in flist:
            img = Image.open(image).convert('L').resize((img_size, img_size))
            img = np.array(img)
            img = img.astype(np.float64) / 255.0
            data_sum += np.sum(img)
            data_std_sum += np.std(img)
            cnt = cnt+1
    os.chdir(top_path)
    data_mean = data_sum /(cnt*img_size*img_size)
    data_std = data_std_sum/cnt
    return data_mean,data_std,my_categories

# %% [markdown]
# I have 3 Convolutional Networks which I will be comparing. The different CNN model architectures are defined in the following code block.

# %%
# My proposed first model
class CNN1(nn.Module):
    def __init__(self):
        super().__init__()
        # Define the convolutional layers:
        self.convolutional_layers = nn.Sequential(
            # 1st layer
            # input channels 1=> Grayscale
            nn.Conv2d(in_channels=1, out_channels=64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),  # for normalization, and to accelerate the process
            nn.LeakyReLU(inplace=True),  # activation function
            # Tensor shape (32, 64 , 64, 64)

            # 2st layer
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),  # for normalization, and to accelerate the process
            nn.LeakyReLU(inplace=True),  # activation function

            # 3rd layer
            nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),  # for normalization, and to accelerate the process
            nn.LeakyReLU(inplace=True),  # activation function

            # 4th layer
            nn.Conv2d(in_channels=128, out_channels=64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),  # for normalization, and to accelerate the process
            nn.LeakyReLU(inplace=True),  # activation function

            # 5th layer
            nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            # 6th layer
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

        )

        # Define the Fully connected/ linear layers:
        # No_of_feature = (W-F + 2*P)/S  + 1
        self.linear_layers = nn.Sequential(
            # Randomly zeros out some elements of input tensor
            nn.Dropout(p=0.1),
            nn.Linear(16 * 16 * 128, 1000),
            nn.ReLU(inplace=True),

            nn.Linear(1000, 512),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.1),

            # The output layer)
            nn.Linear(512, 5)
        )

    def forward(self, tensor):
        # calling the convolutional layers defined in my class
        tensor = self.convolutional_layers(tensor)
        # flattening the tensor using view function
        # tensor.size(0) returns the batch size (32) which should
        # remain constant, -1 tells to calc the other dimensions
        # print(tensor.size(0))
        tensor = tensor.view(tensor.size(0), -1)
        # calling the linear layers defined in my class
        tensor = self.linear_layers(tensor)
        return tensor


# My proposed 2nd model or Main/Shallow model
class CNN2(nn.Module):
    def __init__(self):
        super().__init__()
        # Define the convolutional layers:
        self.convolutional_layers = nn.Sequential(
            # 1st layer
            # input channels 1=> Grayscale
            nn.Conv2d(in_channels=1, out_channels=64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),  # for normalization, and to accelerate the process
            nn.LeakyReLU(inplace=True),  # activation function
            # Tensor shape (32, 64 , 64, 64)

            # 2nd layer
            nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            # Tensor shape (32, 64 , 32, 32)

            # 3rd layer
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            # Tensor shape (32, 128 , 16, 16)

        )

        # Define the Fully connected/ linear layers:
        # No_of_feature = (W-F + 2*P)/S  + 1
        self.linear_layers = nn.Sequential(
            # Randomly zeros out some elements of input tensor
            nn.Dropout(p=0.1),
            nn.Linear(16 * 16 * 128, 1000),
            nn.ReLU(inplace=True),

            nn.Linear(1000, 512),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.1),

            # The output layer)
            nn.Linear(512, 5)
        )

    def forward(self, tensor):
        # calling the convolutional layers defined in my class
        tensor = self.convolutional_layers(tensor)
        # flattening the tensor using view function
        # tensor.size(0) returns the batch size (32) which should
        # remain constant, -1 tells to calc the other dimensions
        # print(tensor.size(0))
        tensor = tensor.view(tensor.size(0), -1)
        # calling the linear layers defined in my class
        tensor = self.linear_layers(tensor)
        return tensor


# My proposed 3rd model
class CNN3(nn.Module):
    def __init__(self):
        super().__init__()
        # Define the convolutional layers:
        self.convolutional_layers = nn.Sequential(
            # 1st layer
            # input channels 1=> Grayscale
            nn.Conv2d(in_channels=1, out_channels=64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),  # for normalization, and to accelerate the process
            nn.LeakyReLU(inplace=True),  # activation function
            # Tensor shape (32, 64 , 64, 64)

            # 2st layer
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),  # for normalization, and to accelerate the process
            nn.LeakyReLU(inplace=True),  # activation function

            # 3rd layer
            nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),  # for normalization, and to accelerate the process
            nn.LeakyReLU(inplace=True),  # activation function
            nn.MaxPool2d(kernel_size=2, stride=2),

            # 4th layer
            nn.Conv2d(in_channels=128, out_channels=64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),  # for normalization, and to accelerate the process
            nn.LeakyReLU(inplace=True),  # activation function
            nn.MaxPool2d(kernel_size=2, stride=2),

            # 5th layer
            nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            # 6th layer
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

        )

        # Define the Fully connected/ linear layers:
        # No_of_feature = (W-F + 2*P)/S  + 1
        self.linear_layers = nn.Sequential(
            # Randomly zeros out some elements of input tensor
            nn.Dropout(p=0.1),
            nn.Linear(4 * 4 * 128, 1000),
            nn.ReLU(inplace=True),

            nn.Linear(1000, 512),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.1),

            # The output layer)
            nn.Linear(512, 5)
        )

    def forward(self, tensor):
        # calling the convolutional layers defined in my class
        tensor = self.convolutional_layers(tensor)
        # flattening the tensor using view function
        # tensor.size(0) returns the batch size (32) which should
        # remain constant, -1 tells to calc the other dimensions
        # print(tensor.size(0))
        tensor = tensor.view(tensor.size(0), -1)
        # calling the linear layers defined in my class
        tensor = self.linear_layers(tensor)
        return tensor

# %% [markdown]
# This method defines the logic for training the model on the given dataset

# %%
def run(model, train_loader, learning_rate, epochs):
    # create an instance of my convolutional network class
    cnn = model()
    lossCriterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(cnn.parameters(), lr=learning_rate)
    total_step = len(train_loader)
    loss_list = []
    accuracy_list = []
    for epoch in range(epochs):
        for i, (images, labels) in enumerate(train_loader):
            output = cnn(images)
            loss = lossCriterion(output, labels)
            loss_list.append((epoch, loss.item()))

            # Applying backpropagation and optimisation
            optimizer.zero_grad()  # no need for gradient in pur classification
            loss.backward()
            optimizer.step()

            # Calculating the accuracy of the cnn during the training process
            totalImages = labels.size(0)
            # max_indexes represents the highest predicted class
            max_elements, max_indexes = torch.max(output.data, 1)
            imagesClassifiedCorrectly = (max_indexes == labels).sum().item()
            accuracy_list.append((epoch, (imagesClassifiedCorrectly / totalImages)))

            print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Accuracy: {:.2f}%'
                  .format(epoch + 1, epochs, i + 1, total_step, loss.item(),
                          (imagesClassifiedCorrectly / totalImages) * 100))
    return cnn

# %% [markdown]
# This is the main driver method, and trains three models using the three proposed CNN architectures on the same dataset.

# %%
def CNN_project_01(model_no_):
    train_loader, test_loader, my_categories = pre_processing()
    if model_no_ == 1:
        cnn_model = run(CNN1, train_loader, learning_rate=0.0001, epochs=8)
        torch.save(cnn_model, top_path + '/trained_model_1.pth')
    elif model_no_ == 2:
        cnn_model = run(CNN2, train_loader, learning_rate=0.0001, epochs=8)
        torch.save(cnn_model, top_path + '/trained_model_2.pth')
    else:
        cnn_model = run(CNN3, train_loader, learning_rate=0.0001, epochs=8)
        torch.save(cnn_model, top_path + '/trained_model_3.pth')

    evaluate(cnn_model, test_loader, my_categories)

# %% [markdown]
# In theis code block, we load an already trained model, and perform evaluation on it using the test dataset to determine accuracy and generate the confusion matrix.

# %%
def evaluate(cnnModel, test_loader, my_categories):
    # Set the CNN module in evaluation mode:
    cnnModel.eval()

    # print(summary(cnn, input_size=(1, 64,64)))
    # disable the gradient calculation in test mode
    with torch.no_grad():
        classifiedCorrectly = 0
        totalImages = 0
        for images, labels in test_loader:
            outputs = cnnModel(images)
            max_elements, max_idxs = torch.max(outputs.data, 1)
            totalImages += labels.size(0)
            classifiedCorrectly += (max_idxs == labels).sum().item()

    print('\nTest Accuracy of the model on the {} test images: {} %'
          .format((totalImages),
                  (classifiedCorrectly / totalImages) * 100))
    test_labels = np.asarray(labels, dtype=np.float32)
    pre_labels = np.asarray(max_idxs, dtype=np.float32)

    conf_Mat = confusion_matrix(test_labels, pre_labels)
    print('\n Confusion Matrix\n')
    print(conf_Mat, '\n')

    df = pd.DataFrame(conf_Mat, index=my_categories, columns=my_categories)
    print(df, '\n\n')
    print(classification_report(test_labels, pre_labels, target_names=my_categories))


def CNN_load_trained_model(model_no_):
    train_loader, test_loader, my_categories = pre_processing()
    if model_no_ == 1:
        model = torch.load(top_path + '/trained_model_1.pth')
    elif model_no_ == 2:
        model = torch.load(top_path + '/trained_model_2.pth')
    else:
        model = torch.load(top_path + '/trained_model_3.pth')
    evaluate(model, test_loader, my_categories)

# %% [markdown]
# Main Driver Method

# %%
for model_no in range(1,4): 
  CNN_project_01(model_no)
# Out:
# length of dataset =  1999
# length of training set =  1599
# length of testing set =  400
# Epoch [1/8], Step [1/50], Loss: 1.6541, Accuracy: 21.88%
# Epoch [1/8], Step [2/50], Loss: 1.6053, Accuracy: 25.00%
# Epoch [1/8], Step [3/50], Loss: 1.6495, Accuracy: 28.12%
# Epoch [1/8], Step [4/50], Loss: 1.6122, Accuracy: 18.75%
# Epoch [1/8], Step [5/50], Loss: 1.5337, Accuracy: 43.75%
# Epoch [1/8], Step [6/50], Loss: 1.4767, Accuracy: 40.62%
# Epoch [1/8], Step [7/50], Loss: 1.4095, Accuracy: 59.38%
# Epoch [1/8], Step [8/50], Loss: 1.4314, Accuracy: 43.75%
# Epoch [1/8], Step [9/50], Loss: 1.3524, Accuracy: 59.38%
# Epoch [1/8], Step [10/50], Loss: 1.3739, Accuracy: 56.25%
# Epoch [1/8], Step [11/50], Loss: 1.3721, Accuracy: 43.75%
# Epoch [1/8], Step [12/50], Loss: 1.3056, Accuracy: 53.12%
# Epoch [1/8], Step [13/50], Loss: 1.2156, Accuracy: 59.38%
# Epoch [1/8], Step [14/50], Loss: 1.2971, Accuracy: 34.38%
# Epoch [1/8], Step [15/50], Loss: 1.2771, Accuracy: 43.75%
# Epoch [1/8], Step [16/50], Loss: 1.1870, Accuracy: 62.50%
# Epoch [1/8], Step [17/50], Loss: 1.2491, Accuracy: 53.12%
# Epoch [1/8], Step [18/50], Loss: 1.2487, Accuracy: 50.00%
# Epoch [1/8], Step [19/50], Loss: 1.1556, Accuracy: 50.00%
# Epoch [1/8], Step [20/50], Loss: 1.2161, Accuracy: 50.00%
# Epoch [1/8], Step [21/50], Loss: 1.0958, Accuracy: 59.38%
# Epoch [1/8], Step [22/50], Loss: 1.2594, Accuracy: 40.62%
# Epoch [1/8], Step [23/50], Loss: 0.9704, Accuracy: 71.88%
# Epoch [1/8], Step [24/50], Loss: 0.9107, Accuracy: 68.75%
# Epoch [1/8], Step [25/50], Loss: 1.2311, Accuracy: 50.00%
# Epoch [1/8], Step [26/50], Loss: 1.1108, Accuracy: 59.38%
# Epoch [1/8], Step [27/50], Loss: 0.9680, Accuracy: 75.00%
# Epoch [1/8], Step [28/50], Loss: 1.0178, Accuracy: 65.62%
# Epoch [1/8], Step [29/50], Loss: 0.9455, Accuracy: 59.38%
# Epoch [1/8], Step [30/50], Loss: 0.9800, Accuracy: 59.38%
# Epoch [1/8], Step [31/50], Loss: 1.1190, Accuracy: 56.25%
# Epoch [1/8], Step [32/50], Loss: 0.9862, Accuracy: 59.38%
# Epoch [1/8], Step [33/50], Loss: 1.0670, Accuracy: 50.00%
# Epoch [1/8], Step [34/50], Loss: 0.8169, Accuracy: 71.88%
# Epoch [1/8], Step [35/50], Loss: 0.9296, Accuracy: 65.62%
# Epoch [1/8], Step [36/50], Loss: 1.2521, Accuracy: 46.88%
# Epoch [1/8], Step [37/50], Loss: 0.9087, Accuracy: 62.50%
# Epoch [1/8], Step [38/50], Loss: 1.3683, Accuracy: 46.88%
# Epoch [1/8], Step [39/50], Loss: 0.9801, Accuracy: 59.38%
# Epoch [1/8], Step [40/50], Loss: 0.9385, Accuracy: 62.50%
# Epoch [1/8], Step [41/50], Loss: 0.9644, Accuracy: 53.12%
# Epoch [1/8], Step [42/50], Loss: 1.0067, Accuracy: 59.38%
# Epoch [1/8], Step [43/50], Loss: 1.1765, Accuracy: 56.25%
# Epoch [1/8], Step [44/50], Loss: 0.9699, Accuracy: 56.25%
# Epoch [1/8], Step [45/50], Loss: 1.3271, Accuracy: 50.00%
# Epoch [1/8], Step [46/50], Loss: 1.0939, Accuracy: 59.38%
# Epoch [1/8], Step [47/50], Loss: 0.9227, Accuracy: 59.38%
# Epoch [1/8], Step [48/50], Loss: 0.9146, Accuracy: 59.38%
# Epoch [1/8], Step [49/50], Loss: 0.8944, Accuracy: 62.50%
# Epoch [1/8], Step [50/50], Loss: 0.7418, Accuracy: 74.19%
# Epoch [2/8], Step [1/50], Loss: 0.8614, Accuracy: 68.75%
# Epoch [2/8], Step [2/50], Loss: 1.0074, Accuracy: 59.38%
# Epoch [2/8], Step [3/50], Loss: 0.8484, Accuracy: 56.25%
# Epoch [2/8], Step [4/50], Loss: 0.8247, Accuracy: 71.88%
# Epoch [2/8], Step [5/50], Loss: 0.8888, Accuracy: 59.38%
# Epoch [2/8], Step [6/50], Loss: 0.7600, Accuracy: 62.50%
# Epoch [2/8], Step [7/50], Loss: 1.2298, Accuracy: 46.88%
# Epoch [2/8], Step [8/50], Loss: 1.1976, Accuracy: 43.75%
# Epoch [2/8], Step [9/50], Loss: 0.8431, Accuracy: 71.88%
# Epoch [2/8], Step [10/50], Loss: 0.9231, Accuracy: 59.38%
# Epoch [2/8], Step [11/50], Loss: 0.7605, Accuracy: 71.88%
# Epoch [2/8], Step [12/50], Loss: 0.8519, Accuracy: 62.50%
# Epoch [2/8], Step [13/50], Loss: 0.7894, Accuracy: 65.62%
# Epoch [2/8], Step [14/50], Loss: 0.7639, Accuracy: 71.88%
# Epoch [2/8], Step [15/50], Loss: 0.9556, Accuracy: 62.50%
# Epoch [2/8], Step [16/50], Loss: 0.8660, Accuracy: 53.12%
# Epoch [2/8], Step [17/50], Loss: 0.7767, Accuracy: 68.75%
# Epoch [2/8], Step [18/50], Loss: 1.0751, Accuracy: 53.12%
# Epoch [2/8], Step [19/50], Loss: 0.8463, Accuracy: 71.88%
# Epoch [2/8], Step [20/50], Loss: 0.8655, Accuracy: 59.38%
# Epoch [2/8], Step [21/50], Loss: 1.0377, Accuracy: 62.50%
# Epoch [2/8], Step [22/50], Loss: 0.8265, Accuracy: 59.38%
# Epoch [2/8], Step [23/50], Loss: 0.7937, Accuracy: 68.75%
# Epoch [2/8], Step [24/50], Loss: 0.6959, Accuracy: 81.25%
# Epoch [2/8], Step [25/50], Loss: 0.8771, Accuracy: 68.75%
# Epoch [2/8], Step [26/50], Loss: 0.7308, Accuracy: 62.50%
# Epoch [2/8], Step [27/50], Loss: 0.9935, Accuracy: 59.38%
# Epoch [2/8], Step [28/50], Loss: 0.7651, Accuracy: 68.75%
# Epoch [2/8], Step [29/50], Loss: 0.8916, Accuracy: 68.75%
# Epoch [2/8], Step [30/50], Loss: 0.9072, Accuracy: 59.38%
# Epoch [2/8], Step [31/50], Loss: 0.7560, Accuracy: 78.12%
# Epoch [2/8], Step [32/50], Loss: 0.7359, Accuracy: 71.88%
# Epoch [2/8], Step [33/50], Loss: 0.8446, Accuracy: 68.75%
# Epoch [2/8], Step [34/50], Loss: 0.8802, Accuracy: 59.38%
# Epoch [2/8], Step [35/50], Loss: 1.2241, Accuracy: 46.88%
# Epoch [2/8], Step [36/50], Loss: 0.8131, Accuracy: 68.75%
# Epoch [2/8], Step [37/50], Loss: 0.9065, Accuracy: 59.38%
# Epoch [2/8], Step [38/50], Loss: 0.9740, Accuracy: 56.25%
# Epoch [2/8], Step [39/50], Loss: 0.7722, Accuracy: 68.75%
# Epoch [2/8], Step [40/50], Loss: 0.6318, Accuracy: 75.00%
# Epoch [2/8], Step [41/50], Loss: 0.8799, Accuracy: 62.50%
# Epoch [2/8], Step [42/50], Loss: 0.7144, Accuracy: 62.50%
# Epoch [2/8], Step [43/50], Loss: 0.7683, Accuracy: 62.50%
# Epoch [2/8], Step [44/50], Loss: 0.8732, Accuracy: 62.50%
# Epoch [2/8], Step [45/50], Loss: 0.8690, Accuracy: 71.88%
# Epoch [2/8], Step [46/50], Loss: 0.7069, Accuracy: 65.62%
# Epoch [2/8], Step [47/50], Loss: 0.7192, Accuracy: 81.25%
# Epoch [2/8], Step [48/50], Loss: 0.5346, Accuracy: 81.25%
# Epoch [2/8], Step [49/50], Loss: 1.0793, Accuracy: 46.88%
# Epoch [2/8], Step [50/50], Loss: 0.5716, Accuracy: 80.65%
# Epoch [3/8], Step [1/50], Loss: 0.5243, Accuracy: 84.38%
# Epoch [3/8], Step [2/50], Loss: 0.6503, Accuracy: 75.00%
# Epoch [3/8], Step [3/50], Loss: 0.7873, Accuracy: 71.88%
# Epoch [3/8], Step [4/50], Loss: 0.7135, Accuracy: 71.88%
# Epoch [3/8], Step [5/50], Loss: 0.7115, Accuracy: 71.88%
# Epoch [3/8], Step [6/50], Loss: 0.6207, Accuracy: 71.88%
# Epoch [3/8], Step [7/50], Loss: 0.5682, Accuracy: 81.25%
# Epoch [3/8], Step [8/50], Loss: 0.6088, Accuracy: 81.25%
# Epoch [3/8], Step [9/50], Loss: 0.7571, Accuracy: 71.88%
# Epoch [3/8], Step [10/50], Loss: 0.7158, Accuracy: 78.12%
# Epoch [3/8], Step [11/50], Loss: 0.6079, Accuracy: 78.12%
# Epoch [3/8], Step [12/50], Loss: 0.5753, Accuracy: 84.38%
# Epoch [3/8], Step [13/50], Loss: 0.6409, Accuracy: 78.12%
# Epoch [3/8], Step [14/50], Loss: 0.4599, Accuracy: 90.62%
# Epoch [3/8], Step [15/50], Loss: 0.5109, Accuracy: 81.25%
# Epoch [3/8], Step [16/50], Loss: 0.6643, Accuracy: 78.12%
# Epoch [3/8], Step [17/50], Loss: 0.5581, Accuracy: 84.38%
# Epoch [3/8], Step [18/50], Loss: 0.6497, Accuracy: 68.75%
# Epoch [3/8], Step [19/50], Loss: 0.8039, Accuracy: 65.62%
# Epoch [3/8], Step [20/50], Loss: 0.9480, Accuracy: 59.38%
# Epoch [3/8], Step [21/50], Loss: 0.8382, Accuracy: 62.50%
# Epoch [3/8], Step [22/50], Loss: 0.6196, Accuracy: 75.00%
# Epoch [3/8], Step [23/50], Loss: 0.5356, Accuracy: 81.25%
# Epoch [3/8], Step [24/50], Loss: 0.6462, Accuracy: 71.88%
# Epoch [3/8], Step [25/50], Loss: 0.5093, Accuracy: 81.25%
# Epoch [3/8], Step [26/50], Loss: 0.5651, Accuracy: 81.25%
# Epoch [3/8], Step [27/50], Loss: 0.6378, Accuracy: 78.12%
# Epoch [3/8], Step [28/50], Loss: 0.6185, Accuracy: 75.00%
# Epoch [3/8], Step [29/50], Loss: 0.7787, Accuracy: 65.62%
# Epoch [3/8], Step [30/50], Loss: 0.5561, Accuracy: 81.25%
# Epoch [3/8], Step [31/50], Loss: 0.4614, Accuracy: 87.50%
# Epoch [3/8], Step [32/50], Loss: 0.8204, Accuracy: 71.88%
# Epoch [3/8], Step [33/50], Loss: 0.8641, Accuracy: 65.62%
# Epoch [3/8], Step [34/50], Loss: 0.6471, Accuracy: 81.25%
# Epoch [3/8], Step [35/50], Loss: 0.5659, Accuracy: 75.00%
# Epoch [3/8], Step [36/50], Loss: 0.5814, Accuracy: 84.38%
# Epoch [3/8], Step [37/50], Loss: 0.6531, Accuracy: 75.00%
# Epoch [3/8], Step [38/50], Loss: 0.6546, Accuracy: 78.12%
# Epoch [3/8], Step [39/50], Loss: 0.6764, Accuracy: 75.00%
# Epoch [3/8], Step [40/50], Loss: 0.7038, Accuracy: 84.38%
# Epoch [3/8], Step [41/50], Loss: 0.6737, Accuracy: 78.12%
# Epoch [3/8], Step [42/50], Loss: 0.7003, Accuracy: 71.88%
# Epoch [3/8], Step [43/50], Loss: 0.6979, Accuracy: 78.12%
# Epoch [3/8], Step [44/50], Loss: 0.7329, Accuracy: 68.75%
# Epoch [3/8], Step [45/50], Loss: 0.7305, Accuracy: 68.75%
# Epoch [3/8], Step [46/50], Loss: 0.5836, Accuracy: 75.00%
# Epoch [3/8], Step [47/50], Loss: 0.5118, Accuracy: 78.12%
# Epoch [3/8], Step [48/50], Loss: 0.4644, Accuracy: 81.25%
# Epoch [3/8], Step [49/50], Loss: 0.6562, Accuracy: 78.12%
# Epoch [3/8], Step [50/50], Loss: 0.7802, Accuracy: 70.97%
# Epoch [4/8], Step [1/50], Loss: 0.4479, Accuracy: 90.62%
# Epoch [4/8], Step [2/50], Loss: 0.5088, Accuracy: 78.12%
# Epoch [4/8], Step [3/50], Loss: 0.4130, Accuracy: 87.50%
# Epoch [4/8], Step [4/50], Loss: 0.5425, Accuracy: 81.25%
# Epoch [4/8], Step [5/50], Loss: 0.3868, Accuracy: 90.62%
# Epoch [4/8], Step [6/50], Loss: 0.5117, Accuracy: 81.25%
# Epoch [4/8], Step [7/50], Loss: 0.6567, Accuracy: 75.00%
# Epoch [4/8], Step [8/50], Loss: 0.6936, Accuracy: 75.00%
# Epoch [4/8], Step [9/50], Loss: 0.6841, Accuracy: 68.75%
# Epoch [4/8], Step [10/50], Loss: 0.4219, Accuracy: 84.38%
# Epoch [4/8], Step [11/50], Loss: 0.5721, Accuracy: 75.00%
# Epoch [4/8], Step [12/50], Loss: 0.5507, Accuracy: 75.00%
# Epoch [4/8], Step [13/50], Loss: 0.6986, Accuracy: 71.88%
# Epoch [4/8], Step [14/50], Loss: 0.8109, Accuracy: 71.88%
# Epoch [4/8], Step [15/50], Loss: 0.3914, Accuracy: 90.62%
# Epoch [4/8], Step [16/50], Loss: 0.6317, Accuracy: 75.00%
# Epoch [4/8], Step [17/50], Loss: 0.6534, Accuracy: 65.62%
# Epoch [4/8], Step [18/50], Loss: 0.4422, Accuracy: 81.25%
# Epoch [4/8], Step [19/50], Loss: 0.4999, Accuracy: 84.38%
# Epoch [4/8], Step [20/50], Loss: 0.4992, Accuracy: 81.25%
# Epoch [4/8], Step [21/50], Loss: 0.3880, Accuracy: 93.75%
# Epoch [4/8], Step [22/50], Loss: 0.3486, Accuracy: 84.38%
# Epoch [4/8], Step [23/50], Loss: 0.6656, Accuracy: 78.12%
# Epoch [4/8], Step [24/50], Loss: 0.5299, Accuracy: 81.25%
# Epoch [4/8], Step [25/50], Loss: 0.5839, Accuracy: 68.75%
# Epoch [4/8], Step [26/50], Loss: 0.4056, Accuracy: 87.50%
# Epoch [4/8], Step [27/50], Loss: 0.5624, Accuracy: 75.00%
# Epoch [4/8], Step [28/50], Loss: 0.2884, Accuracy: 90.62%
# Epoch [4/8], Step [29/50], Loss: 0.2793, Accuracy: 93.75%
# Epoch [4/8], Step [30/50], Loss: 0.7692, Accuracy: 65.62%
# Epoch [4/8], Step [31/50], Loss: 0.7455, Accuracy: 62.50%
# Epoch [4/8], Step [32/50], Loss: 0.4198, Accuracy: 87.50%
# Epoch [4/8], Step [33/50], Loss: 0.5833, Accuracy: 75.00%
# Epoch [4/8], Step [34/50], Loss: 0.6663, Accuracy: 78.12%
# Epoch [4/8], Step [35/50], Loss: 0.5066, Accuracy: 81.25%
# Epoch [4/8], Step [36/50], Loss: 0.4913, Accuracy: 75.00%
# Epoch [4/8], Step [37/50], Loss: 0.4642, Accuracy: 81.25%
# Epoch [4/8], Step [38/50], Loss: 0.4945, Accuracy: 78.12%
# Epoch [4/8], Step [39/50], Loss: 0.4778, Accuracy: 78.12%
# Epoch [4/8], Step [40/50], Loss: 0.5084, Accuracy: 87.50%
# Epoch [4/8], Step [41/50], Loss: 0.3606, Accuracy: 81.25%
# Epoch [4/8], Step [42/50], Loss: 0.5148, Accuracy: 81.25%
# Epoch [4/8], Step [43/50], Loss: 0.4944, Accuracy: 75.00%
# Epoch [4/8], Step [44/50], Loss: 0.4986, Accuracy: 81.25%
# Epoch [4/8], Step [45/50], Loss: 0.6069, Accuracy: 68.75%
# Epoch [4/8], Step [46/50], Loss: 0.5672, Accuracy: 71.88%
# Epoch [4/8], Step [47/50], Loss: 0.4977, Accuracy: 75.00%
# Epoch [4/8], Step [48/50], Loss: 0.4211, Accuracy: 84.38%
# Epoch [4/8], Step [49/50], Loss: 0.6037, Accuracy: 71.88%
# Epoch [4/8], Step [50/50], Loss: 0.4353, Accuracy: 90.32%
# Epoch [5/8], Step [1/50], Loss: 0.3903, Accuracy: 87.50%
# Epoch [5/8], Step [2/50], Loss: 0.4175, Accuracy: 84.38%
# Epoch [5/8], Step [3/50], Loss: 0.5583, Accuracy: 71.88%
# Epoch [5/8], Step [4/50], Loss: 0.5980, Accuracy: 81.25%
# Epoch [5/8], Step [5/50], Loss: 0.3824, Accuracy: 87.50%
# Epoch [5/8], Step [6/50], Loss: 0.2986, Accuracy: 93.75%
# Epoch [5/8], Step [7/50], Loss: 0.3601, Accuracy: 87.50%
# Epoch [5/8], Step [8/50], Loss: 0.4329, Accuracy: 84.38%
# Epoch [5/8], Step [9/50], Loss: 0.4954, Accuracy: 75.00%
# Epoch [5/8], Step [10/50], Loss: 0.2919, Accuracy: 93.75%
# Epoch [5/8], Step [11/50], Loss: 0.5924, Accuracy: 81.25%
# Epoch [5/8], Step [12/50], Loss: 0.5164, Accuracy: 78.12%
# Epoch [5/8], Step [13/50], Loss: 0.4073, Accuracy: 81.25%
# Epoch [5/8], Step [14/50], Loss: 0.3127, Accuracy: 90.62%
# Epoch [5/8], Step [15/50], Loss: 0.4118, Accuracy: 81.25%
# Epoch [5/8], Step [16/50], Loss: 0.3270, Accuracy: 87.50%
# Epoch [5/8], Step [17/50], Loss: 0.7063, Accuracy: 65.62%
# Epoch [5/8], Step [18/50], Loss: 0.4291, Accuracy: 81.25%
# Epoch [5/8], Step [19/50], Loss: 0.5144, Accuracy: 68.75%
# Epoch [5/8], Step [20/50], Loss: 0.2437, Accuracy: 93.75%
# Epoch [5/8], Step [21/50], Loss: 0.3932, Accuracy: 87.50%
# Epoch [5/8], Step [22/50], Loss: 0.2626, Accuracy: 93.75%
# Epoch [5/8], Step [23/50], Loss: 0.3499, Accuracy: 90.62%
# Epoch [5/8], Step [24/50], Loss: 0.3537, Accuracy: 90.62%
# Epoch [5/8], Step [25/50], Loss: 0.6920, Accuracy: 68.75%
# Epoch [5/8], Step [26/50], Loss: 0.3388, Accuracy: 90.62%
# Epoch [5/8], Step [27/50], Loss: 0.3644, Accuracy: 90.62%
# Epoch [5/8], Step [28/50], Loss: 0.2274, Accuracy: 93.75%
# Epoch [5/8], Step [29/50], Loss: 0.3328, Accuracy: 90.62%
# Epoch [5/8], Step [30/50], Loss: 0.4276, Accuracy: 87.50%
# Epoch [5/8], Step [31/50], Loss: 0.3745, Accuracy: 87.50%
# Epoch [5/8], Step [32/50], Loss: 0.5085, Accuracy: 75.00%
# Epoch [5/8], Step [33/50], Loss: 0.3287, Accuracy: 93.75%
# Epoch [5/8], Step [34/50], Loss: 0.3272, Accuracy: 87.50%
# Epoch [5/8], Step [35/50], Loss: 0.4671, Accuracy: 81.25%
# Epoch [5/8], Step [36/50], Loss: 0.4515, Accuracy: 84.38%
# Epoch [5/8], Step [37/50], Loss: 0.4103, Accuracy: 81.25%
# Epoch [5/8], Step [38/50], Loss: 0.4094, Accuracy: 90.62%
# Epoch [5/8], Step [39/50], Loss: 0.4749, Accuracy: 71.88%
# Epoch [5/8], Step [40/50], Loss: 0.4078, Accuracy: 84.38%
# Epoch [5/8], Step [41/50], Loss: 0.3925, Accuracy: 84.38%
# Epoch [5/8], Step [42/50], Loss: 0.3568, Accuracy: 87.50%
# Epoch [5/8], Step [43/50], Loss: 0.3190, Accuracy: 90.62%
# Epoch [5/8], Step [44/50], Loss: 0.2888, Accuracy: 90.62%
# Epoch [5/8], Step [45/50], Loss: 0.5350, Accuracy: 71.88%
# Epoch [5/8], Step [46/50], Loss: 0.4246, Accuracy: 87.50%
# Epoch [5/8], Step [47/50], Loss: 0.2030, Accuracy: 93.75%
# Epoch [5/8], Step [48/50], Loss: 0.4672, Accuracy: 81.25%
# Epoch [5/8], Step [49/50], Loss: 0.1736, Accuracy: 96.88%
# Epoch [5/8], Step [50/50], Loss: 0.7481, Accuracy: 64.52%
# Epoch [6/8], Step [1/50], Loss: 0.2437, Accuracy: 93.75%
# Epoch [6/8], Step [2/50], Loss: 0.2041, Accuracy: 96.88%
# Epoch [6/8], Step [3/50], Loss: 0.3226, Accuracy: 93.75%
# Epoch [6/8], Step [4/50], Loss: 0.3606, Accuracy: 84.38%
# Epoch [6/8], Step [5/50], Loss: 0.3059, Accuracy: 90.62%
# Epoch [6/8], Step [6/50], Loss: 0.3300, Accuracy: 90.62%
# Epoch [6/8], Step [7/50], Loss: 0.1426, Accuracy: 96.88%
# Epoch [6/8], Step [8/50], Loss: 0.3512, Accuracy: 87.50%
# Epoch [6/8], Step [9/50], Loss: 0.2852, Accuracy: 93.75%
# Epoch [6/8], Step [10/50], Loss: 0.2520, Accuracy: 87.50%
# Epoch [6/8], Step [11/50], Loss: 0.5163, Accuracy: 78.12%
# Epoch [6/8], Step [12/50], Loss: 0.3542, Accuracy: 87.50%
# Epoch [6/8], Step [13/50], Loss: 0.1887, Accuracy: 96.88%
# Epoch [6/8], Step [14/50], Loss: 0.2319, Accuracy: 96.88%
# Epoch [6/8], Step [15/50], Loss: 0.3772, Accuracy: 87.50%
# Epoch [6/8], Step [16/50], Loss: 0.3392, Accuracy: 87.50%
# Epoch [6/8], Step [17/50], Loss: 0.3872, Accuracy: 87.50%
# Epoch [6/8], Step [18/50], Loss: 0.1519, Accuracy: 96.88%
# Epoch [6/8], Step [19/50], Loss: 0.6242, Accuracy: 78.12%
# Epoch [6/8], Step [20/50], Loss: 0.2751, Accuracy: 93.75%
# Epoch [6/8], Step [21/50], Loss: 0.2189, Accuracy: 90.62%
# Epoch [6/8], Step [22/50], Loss: 0.4421, Accuracy: 78.12%
# Epoch [6/8], Step [23/50], Loss: 0.3635, Accuracy: 81.25%
# Epoch [6/8], Step [24/50], Loss: 0.3643, Accuracy: 87.50%
# Epoch [6/8], Step [25/50], Loss: 0.2698, Accuracy: 93.75%
# Epoch [6/8], Step [26/50], Loss: 0.2695, Accuracy: 93.75%
# Epoch [6/8], Step [27/50], Loss: 0.3680, Accuracy: 87.50%
# Epoch [6/8], Step [28/50], Loss: 0.2427, Accuracy: 96.88%
# Epoch [6/8], Step [29/50], Loss: 0.2130, Accuracy: 93.75%
# Epoch [6/8], Step [30/50], Loss: 0.1527, Accuracy: 100.00%
# Epoch [6/8], Step [31/50], Loss: 0.3193, Accuracy: 84.38%
# Epoch [6/8], Step [32/50], Loss: 0.2723, Accuracy: 90.62%
# Epoch [6/8], Step [33/50], Loss: 0.3371, Accuracy: 84.38%
# Epoch [6/8], Step [34/50], Loss: 0.3744, Accuracy: 87.50%
# Epoch [6/8], Step [35/50], Loss: 0.2862, Accuracy: 90.62%
# Epoch [6/8], Step [36/50], Loss: 0.3265, Accuracy: 90.62%
# Epoch [6/8], Step [37/50], Loss: 0.2870, Accuracy: 87.50%
# Epoch [6/8], Step [38/50], Loss: 0.2404, Accuracy: 93.75%
# Epoch [6/8], Step [39/50], Loss: 0.2632, Accuracy: 90.62%
# Epoch [6/8], Step [40/50], Loss: 0.4190, Accuracy: 84.38%
# Epoch [6/8], Step [41/50], Loss: 0.1909, Accuracy: 93.75%
# Epoch [6/8], Step [42/50], Loss: 0.2470, Accuracy: 87.50%
# Epoch [6/8], Step [43/50], Loss: 0.1428, Accuracy: 100.00%
# Epoch [6/8], Step [44/50], Loss: 0.2410, Accuracy: 87.50%
# Epoch [6/8], Step [45/50], Loss: 0.2549, Accuracy: 90.62%
# Epoch [6/8], Step [46/50], Loss: 0.3544, Accuracy: 84.38%
# Epoch [6/8], Step [47/50], Loss: 0.2519, Accuracy: 93.75%
# Epoch [6/8], Step [48/50], Loss: 0.2003, Accuracy: 96.88%
# Epoch [6/8], Step [49/50], Loss: 0.2876, Accuracy: 84.38%
# Epoch [6/8], Step [50/50], Loss: 0.2186, Accuracy: 96.77%
# Epoch [7/8], Step [1/50], Loss: 0.1235, Accuracy: 96.88%
# Epoch [7/8], Step [2/50], Loss: 0.1990, Accuracy: 90.62%
# Epoch [7/8], Step [3/50], Loss: 0.2034, Accuracy: 90.62%
# Epoch [7/8], Step [4/50], Loss: 0.2155, Accuracy: 90.62%
# Epoch [7/8], Step [5/50], Loss: 0.1623, Accuracy: 96.88%
# Epoch [7/8], Step [6/50], Loss: 0.1843, Accuracy: 93.75%
# Epoch [7/8], Step [7/50], Loss: 0.1969, Accuracy: 96.88%
# Epoch [7/8], Step [8/50], Loss: 0.1802, Accuracy: 96.88%
# Epoch [7/8], Step [9/50], Loss: 0.1865, Accuracy: 96.88%
# Epoch [7/8], Step [10/50], Loss: 0.2306, Accuracy: 96.88%
# Epoch [7/8], Step [11/50], Loss: 0.2307, Accuracy: 93.75%
# Epoch [7/8], Step [12/50], Loss: 0.1379, Accuracy: 96.88%
# Epoch [7/8], Step [13/50], Loss: 0.0857, Accuracy: 100.00%
# Epoch [7/8], Step [14/50], Loss: 0.1598, Accuracy: 93.75%
# Epoch [7/8], Step [15/50], Loss: 0.1388, Accuracy: 93.75%
# Epoch [7/8], Step [16/50], Loss: 0.0835, Accuracy: 100.00%
# Epoch [7/8], Step [17/50], Loss: 0.2510, Accuracy: 93.75%
# Epoch [7/8], Step [18/50], Loss: 0.1111, Accuracy: 96.88%
# Epoch [7/8], Step [19/50], Loss: 0.2532, Accuracy: 93.75%
# Epoch [7/8], Step [20/50], Loss: 0.1443, Accuracy: 100.00%
# Epoch [7/8], Step [21/50], Loss: 0.1757, Accuracy: 93.75%
# Epoch [7/8], Step [22/50], Loss: 0.2114, Accuracy: 93.75%
# Epoch [7/8], Step [23/50], Loss: 0.1010, Accuracy: 96.88%
# Epoch [7/8], Step [24/50], Loss: 0.0835, Accuracy: 96.88%
# Epoch [7/8], Step [25/50], Loss: 0.1024, Accuracy: 100.00%
# Epoch [7/8], Step [26/50], Loss: 0.1937, Accuracy: 87.50%
# Epoch [7/8], Step [27/50], Loss: 0.2177, Accuracy: 93.75%
# Epoch [7/8], Step [28/50], Loss: 0.1565, Accuracy: 96.88%
# Epoch [7/8], Step [29/50], Loss: 0.0922, Accuracy: 100.00%
# Epoch [7/8], Step [30/50], Loss: 0.1823, Accuracy: 93.75%
# Epoch [7/8], Step [31/50], Loss: 0.2414, Accuracy: 90.62%
# Epoch [7/8], Step [32/50], Loss: 0.1606, Accuracy: 96.88%
# Epoch [7/8], Step [33/50], Loss: 0.1761, Accuracy: 93.75%
# Epoch [7/8], Step [34/50], Loss: 0.2305, Accuracy: 90.62%
# Epoch [7/8], Step [35/50], Loss: 0.2895, Accuracy: 84.38%
# Epoch [7/8], Step [36/50], Loss: 0.0819, Accuracy: 100.00%
# Epoch [7/8], Step [37/50], Loss: 0.1685, Accuracy: 93.75%
# Epoch [7/8], Step [38/50], Loss: 0.3295, Accuracy: 81.25%
# Epoch [7/8], Step [39/50], Loss: 0.1913, Accuracy: 96.88%
# Epoch [7/8], Step [40/50], Loss: 0.3837, Accuracy: 87.50%
# Epoch [7/8], Step [41/50], Loss: 0.1207, Accuracy: 100.00%
# Epoch [7/8], Step [42/50], Loss: 0.2331, Accuracy: 84.38%
# Epoch [7/8], Step [43/50], Loss: 0.1587, Accuracy: 96.88%
# Epoch [7/8], Step [44/50], Loss: 0.2218, Accuracy: 90.62%
# Epoch [7/8], Step [45/50], Loss: 0.0660, Accuracy: 100.00%
# Epoch [7/8], Step [46/50], Loss: 0.2280, Accuracy: 90.62%
# Epoch [7/8], Step [47/50], Loss: 0.3326, Accuracy: 87.50%
# Epoch [7/8], Step [48/50], Loss: 0.2074, Accuracy: 93.75%
# Epoch [7/8], Step [49/50], Loss: 0.2285, Accuracy: 96.88%
# Epoch [7/8], Step [50/50], Loss: 0.1950, Accuracy: 90.32%
# Epoch [8/8], Step [1/50], Loss: 0.1205, Accuracy: 96.88%
# Epoch [8/8], Step [2/50], Loss: 0.1836, Accuracy: 96.88%
# Epoch [8/8], Step [3/50], Loss: 0.1437, Accuracy: 93.75%
# Epoch [8/8], Step [4/50], Loss: 0.1621, Accuracy: 100.00%
# Epoch [8/8], Step [5/50], Loss: 0.1320, Accuracy: 96.88%
# Epoch [8/8], Step [6/50], Loss: 0.0823, Accuracy: 100.00%
# Epoch [8/8], Step [7/50], Loss: 0.1603, Accuracy: 93.75%
# Epoch [8/8], Step [8/50], Loss: 0.0949, Accuracy: 100.00%
# Epoch [8/8], Step [9/50], Loss: 0.2222, Accuracy: 90.62%
# Epoch [8/8], Step [10/50], Loss: 0.1900, Accuracy: 93.75%
# Epoch [8/8], Step [11/50], Loss: 0.0839, Accuracy: 100.00%
# Epoch [8/8], Step [12/50], Loss: 0.0572, Accuracy: 96.88%
# Epoch [8/8], Step [13/50], Loss: 0.3121, Accuracy: 87.50%
# Epoch [8/8], Step [14/50], Loss: 0.3035, Accuracy: 84.38%
# Epoch [8/8], Step [15/50], Loss: 0.1835, Accuracy: 93.75%
# Epoch [8/8], Step [16/50], Loss: 0.2132, Accuracy: 90.62%
# Epoch [8/8], Step [17/50], Loss: 0.1320, Accuracy: 93.75%
# Epoch [8/8], Step [18/50], Loss: 0.3698, Accuracy: 84.38%
# Epoch [8/8], Step [19/50], Loss: 0.0459, Accuracy: 100.00%
# Epoch [8/8], Step [20/50], Loss: 0.2307, Accuracy: 87.50%
# Epoch [8/8], Step [21/50], Loss: 0.2036, Accuracy: 87.50%
# Epoch [8/8], Step [22/50], Loss: 0.2532, Accuracy: 90.62%
# Epoch [8/8], Step [23/50], Loss: 0.1355, Accuracy: 96.88%
# Epoch [8/8], Step [24/50], Loss: 0.0956, Accuracy: 100.00%
# Epoch [8/8], Step [25/50], Loss: 0.0718, Accuracy: 100.00%
# Epoch [8/8], Step [26/50], Loss: 0.0689, Accuracy: 100.00%
# Epoch [8/8], Step [27/50], Loss: 0.1180, Accuracy: 96.88%
# Epoch [8/8], Step [28/50], Loss: 0.1470, Accuracy: 93.75%
# Epoch [8/8], Step [29/50], Loss: 0.1699, Accuracy: 90.62%
# Epoch [8/8], Step [30/50], Loss: 0.2785, Accuracy: 87.50%
# Epoch [8/8], Step [31/50], Loss: 0.1725, Accuracy: 93.75%
# Epoch [8/8], Step [32/50], Loss: 0.1224, Accuracy: 100.00%
# Epoch [8/8], Step [33/50], Loss: 0.1221, Accuracy: 100.00%
# Epoch [8/8], Step [34/50], Loss: 0.0968, Accuracy: 96.88%
# Epoch [8/8], Step [35/50], Loss: 0.1752, Accuracy: 93.75%
# Epoch [8/8], Step [36/50], Loss: 0.1707, Accuracy: 93.75%
# Epoch [8/8], Step [37/50], Loss: 0.1501, Accuracy: 96.88%
# Epoch [8/8], Step [38/50], Loss: 0.1396, Accuracy: 96.88%
# Epoch [8/8], Step [39/50], Loss: 0.2374, Accuracy: 81.25%
# Epoch [8/8], Step [40/50], Loss: 0.0906, Accuracy: 96.88%
# Epoch [8/8], Step [41/50], Loss: 0.0856, Accuracy: 96.88%
# Epoch [8/8], Step [42/50], Loss: 0.1407, Accuracy: 96.88%
# Epoch [8/8], Step [43/50], Loss: 0.0966, Accuracy: 100.00%
# Epoch [8/8], Step [44/50], Loss: 0.2189, Accuracy: 90.62%
# Epoch [8/8], Step [45/50], Loss: 0.1084, Accuracy: 96.88%
# Epoch [8/8], Step [46/50], Loss: 0.1215, Accuracy: 96.88%
# Epoch [8/8], Step [47/50], Loss: 0.1518, Accuracy: 93.75%
# Epoch [8/8], Step [48/50], Loss: 0.0611, Accuracy: 100.00%
# Epoch [8/8], Step [49/50], Loss: 0.1047, Accuracy: 96.88%
# Epoch [8/8], Step [50/50], Loss: 0.0295, Accuracy: 100.00%
#
# Test Accuracy of the model on the 400 test images: 75.75 %
#
#  Confusion Matrix
#
# [[38  4  9 28  1]
#  [ 1 56 12  7  4]
#  [ 3  8 60  9  0]
#  [ 3  1  4 70  2]
#  [ 0  0  0  1 79]]
#
#                    05_WORN_INCORRECT  01_CLOTH  03_FFP2  04_NO  02_SURGICAL
# 05_WORN_INCORRECT                 38         4        9     28            1
# 01_CLOTH                           1        56       12      7            4
# 03_FFP2                            3         8       60      9            0
# 04_NO                              3         1        4     70            2
# 02_SURGICAL                        0         0        0      1           79
#
#
#                    precision    recall  f1-score   support
#
# 05_WORN_INCORRECT       0.84      0.47      0.61        80
#          01_CLOTH       0.81      0.70      0.75        80
#           03_FFP2       0.71      0.75      0.73        80
#             04_NO       0.61      0.88      0.72        80
#       02_SURGICAL       0.92      0.99      0.95        80
#
#          accuracy                           0.76       400
#         macro avg       0.78      0.76      0.75       400
#      weighted avg       0.78      0.76      0.75       400

# %%
#CNN_load_trained_model(model_no_)
